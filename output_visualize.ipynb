# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Production\Geocoded\HistoricTestingAFI_to_geocode_Geocoded.csv')
# Out:
# C:\Users\ho9307\AppData\Local\Temp\ipykernel_30516\3583903154.py:1: DtypeWarning: Columns (21,32,33,34,35,36,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Production\Geocoded\HistoricTestingAFI_to_geocode_Geocoded.csv')

# %%
df.head()
# Out:
#                          dataset  Dupset  PersonID     PEG_ID Last_Name  \
# 0  HistoricTestingAFI (Geocoded)       1   1000313        NaN    Elzein
# 1  HistoricTestingAFI (Geocoded)       1   1001744        NaN   Everett
# 2  HistoricTestingAFI (Geocoded)       1   1002297  MIC004765      HILL
# 3  HistoricTestingAFI (Geocoded)       1   1002400  MCB000833     White
# 4  HistoricTestingAFI (Geocoded)       1   1002913  MIC100314   Jackson
#
#   First_Name                  DOB         Phone       AddressLine1  \
# 0        Ali  1959-06-20 00:00:00  3.139952e+09    153 Rosemary St
# 1    William  1955-02-26 00:00:00  3.136247e+09  19485 Whitcomb St
# 2    DOUGLAS  1955-11-21 00:00:00  5.864412e+09   858 TENNESSEE ST
# 3      Hilda  1960-12-29 00:00:00  3.132697e+09     25354 Rubin Rd
# 4     Janice  1956-01-28 00:00:00  3.139246e+09   20211 Hickory St
#
#                City    Zip     OrderNo            OrderDate  \
# 0  Dearborn Heights  48127  PRO1009474  2020-06-12 00:00:00
# ...

# %%
df = df.drop(columns=['CensusTract', 'GeoPoint'])

# %%
df.to_csv('Production\Geocoded\HistoricTestingAFI_to_geocode_Geocoded_cleaned.csv')
